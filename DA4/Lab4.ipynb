# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Data- Data is MNISt dataset which contains 70000 images

# %%
from keras.datasets import mnist
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# Normalisation

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
x_train.max()
# Out:
# 1.0

# %%
x_train.dtype
# Out:
# dtype('float64')

# %%
x_train=x_train.reshape(-1,784)
x_test=x_test.reshape(-1,784)

# %%
print(x_train.shape)
# Out:
# (60000, 784)

# %%
print(x_test.shape)
# Out:
# (10000, 784)

# %% [markdown]
# Model

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu',input_shape=(784,)), 
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation='softmax'),
    
])

# %%
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 128)               100480
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dense_5 (Dense)             (None, 10)                1290
#
# ...
# Total params: 102282 (399.54 KB)
# Trainable params: 102026 (398.54 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# None

# %%
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10,batch_size=38)
# Out:
# Epoch 1/10
# 1579/1579 [==============================] - 2s 875us/step - loss: 0.3844 - accuracy: 0.8873
# Epoch 2/10
# 1579/1579 [==============================] - 1s 874us/step - loss: 0.2074 - accuracy: 0.9415
# Epoch 3/10
# 1579/1579 [==============================] - 1s 874us/step - loss: 0.1635 - accuracy: 0.9538
# Epoch 4/10
# 1579/1579 [==============================] - 1s 877us/step - loss: 0.1384 - accuracy: 0.9611
# Epoch 5/10
# 1579/1579 [==============================] - 1s 873us/step - loss: 0.1208 - accuracy: 0.9657
# Epoch 6/10
# 1579/1579 [==============================] - 1s 874us/step - loss: 0.1084 - accuracy: 0.9696
# Epoch 7/10
# 1579/1579 [==============================] - 1s 878us/step - loss: 0.0947 - accuracy: 0.9736
# Epoch 8/10
# 1579/1579 [==============================] - 1s 878us/step - loss: 0.0878 - accuracy: 0.9754
# Epoch 9/10
# 1579/1579 [==============================] - 1s 878us/step - loss: 0.0792 - accuracy: 0.9779
# Epoch 10/10
# ...

# %%
loss, acc = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.9742000102996826

# %%
import pickle

# %%
import pickle
with open('Edge', 'wb') as file:
    pickle.dump(model, file)

print("Model saved as 'Edge'")
# Out:
# Model saved as 'Edge'

# %%
import os
file_size_bytes = os.path.getsize('Edge')
file_size_kb = file_size_bytes / 1024

print(f"The size of the model file 'Edge' is: {file_size_kb:.2f} KB")
# Out:
# The size of the model file 'Edge' is: 820.52 KB
